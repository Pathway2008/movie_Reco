# %% [markdown]
# #0.Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# from google.colab import files
# # from google.colab import drive
# import io
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-20d56999cdda> in <module>
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 from google.colab import files
#       6 from google.colab import drive
#       7 import io
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# file = files.upload() # 파일선택

# %%
# !ls -Fcal '/content/drive/My Drive/dataset'
# Out:
# 'ls'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %% [markdown]
# #1.Data load

# %%
movies = pd.read_csv("ml-1m/movies.dat",sep='::',header=None)
ratings = pd.read_csv("ml-1m/ratings.dat",sep='::',header=None)
users = pd.read_csv("ml-1m/users.dat",sep='::',header=None)
# Out:
# <ipython-input-6-95a0019682ff>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   movies = pd.read_csv("ml-1m/movies.dat",sep='::',header=None)
# <ipython-input-6-95a0019682ff>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ratings = pd.read_csv("ml-1m/ratings.dat",sep='::',header=None)
# <ipython-input-6-95a0019682ff>:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# ...

# %%
mov_names = ['MovieID', 'Title', 'Genres']
rat_names = ['UserID','MovieID', 'Rating','Timestamp']
users_names = ['UserID','Gender','Age','Occupation','Zip-code']

# %%
movies.columns = mov_names
ratings.columns = rat_names
users.columns = users_names

# %% [markdown]
# ##1.Data Check

# %%
print(movies.shape)
print(movies.info())
# Out:
# (3883, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   MovieID  3883 non-null   int64
#  1   Title    3883 non-null   object
#  2   Genres   3883 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 91.1+ KB
# None

# %%
movies
# Out:
#       MovieID                               Title  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 3           4            Waiting to Exhale (1995)
# 4           5  Father of the Bride Part II (1995)
# ...       ...                                 ...
# 3878     3948             Meet the Parents (2000)
# 3879     3949          Requiem for a Dream (2000)
# 3880     3950                    Tigerland (2000)
# 3881     3951             Two Family House (2000)
# 3882     3952               Contender, The (2000)
#
#                             Genres
# 0      Animation|Children's|Comedy
# 1     Adventure|Children's|Fantasy
# 2                   Comedy|Romance
# 3                     Comedy|Drama
# 4                           Comedy
# ...                            ...
# 3878                        Comedy
# 3879                         Drama
# 3880                         Drama
# ...

# %%
print(ratings.shape)
print(ratings.info())
# Out:
# (1000209, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   UserID     1000209 non-null  int64
#  1   MovieID    1000209 non-null  int64
#  2   Rating     1000209 non-null  int64
#  3   Timestamp  1000209 non-null  int64
# dtypes: int64(4)
# memory usage: 30.5 MB
# None

# %%
ratings
# Out:
#          UserID  MovieID  Rating  Timestamp
# 0             1     1193       5  978300760
# 1             1      661       3  978302109
# 2             1      914       3  978301968
# 3             1     3408       4  978300275
# 4             1     2355       5  978824291
# ...         ...      ...     ...        ...
# 1000204    6040     1091       1  956716541
# 1000205    6040     1094       5  956704887
# 1000206    6040      562       5  956704746
# 1000207    6040     1096       4  956715648
# 1000208    6040     1097       4  956715569
#
# [1000209 rows x 4 columns]

# %%
print(users.shape)
print(users.info())
# Out:
# (6040, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6040 entries, 0 to 6039
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UserID      6040 non-null   int64
#  1   Gender      6040 non-null   object
#  2   Age         6040 non-null   int64
#  3   Occupation  6040 non-null   int64
#  4   Zip-code    6040 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 236.1+ KB
# None

# %%
#users.drop(['Zip-code'],axis=1,inplace=True)
users
# Out:
#       UserID Gender  Age  Occupation Zip-code
# 0          1      F    1          10    48067
# 1          2      M   56          16    70072
# 2          3      M   25          15    55117
# 3          4      M   45           7    02460
# 4          5      M   25          20    55455
# ...      ...    ...  ...         ...      ...
# 6035    6036      F   25          15    32603
# 6036    6037      F   45           1    76006
# 6037    6038      F   56           1    14706
# 6038    6039      F   45           0    01060
# 6039    6040      M   25           6    11106
#
# [6040 rows x 5 columns]

# %%
movies.isnull().sum()
# Out:
# MovieID    0
# Title      0
# Genres     0
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# UserID       0
# MovieID      0
# Rating       0
# Timestamp    0
# dtype: int64

# %%
users.isnull().sum()
# Out:
# UserID        0
# Gender        0
# Age           0
# Occupation    0
# Zip-code      0
# dtype: int64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   MovieID  3883 non-null   int64
#  1   Title    3883 non-null   object
#  2   Genres   3883 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 91.1+ KB

# %%
ratings.info()
ratings['UserID'].unique() # UserID 6040명
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   UserID     1000209 non-null  int64
#  1   MovieID    1000209 non-null  int64
#  2   Rating     1000209 non-null  int64
#  3   Timestamp  1000209 non-null  int64
# dtypes: int64(4)
# memory usage: 30.5 MB
# array([   1,    2,    3, ..., 6038, 6039, 6040], dtype=int64)

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6040 entries, 0 to 6039
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UserID      6040 non-null   int64
#  1   Gender      6040 non-null   object
#  2   Age         6040 non-null   int64
#  3   Occupation  6040 non-null   int64
#  4   Zip-code    6040 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 236.1+ KB

# %%
mov_rat_table = pd.merge(movies, ratings, on='MovieID')

mov_rat_table.drop(['Timestamp'], axis=1, inplace=True)
mov_rat_table.head()
# Out:
#    MovieID             Title                       Genres  UserID  Rating
# 0        1  Toy Story (1995)  Animation|Children's|Comedy       1       5
# 1        1  Toy Story (1995)  Animation|Children's|Comedy       6       4
# 2        1  Toy Story (1995)  Animation|Children's|Comedy       8       4
# 3        1  Toy Story (1995)  Animation|Children's|Comedy       9       5
# 4        1  Toy Story (1995)  Animation|Children's|Comedy      10       5

# %%
mov_rat_use_table = pd.merge(mov_rat_table, users, how='left')


.set_index('UserID')

y_rating = mov_rat_use_table['Rating']
print(y_rating)
# Out:
#   File "<ipython-input-110-a9a6de7eba07>", line 4
#     .set_index('UserID')
#     ^
# SyntaxError: invalid syntax

# %%
gen_list = ["Action", "Adventure", "Animation", "Children's", "Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", \
            "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller"]

# %%
for gen in gen_list:
    mov_rat_use_table[f"{gen}"] = mov_rat_use_table['Genres'].str.contains(gen)

mov_rat_use_table.head()
# Out:
#    MovieID             Title                       Genres  UserID Gender  Age  \
# 0        1  Toy Story (1995)  Animation|Children's|Comedy       1      F    1
# 1        1  Toy Story (1995)  Animation|Children's|Comedy       6      F   50
# 2        1  Toy Story (1995)  Animation|Children's|Comedy       8      M   25
# 3        1  Toy Story (1995)  Animation|Children's|Comedy       9      M   25
# 4        1  Toy Story (1995)  Animation|Children's|Comedy      10      F   35
#
#    Occupation Zip-code  Action  Adventure  ...  Documentary  Drama  Fantasy  \
# 0          10    48067   False      False  ...        False  False    False
# 1           9    55117   False      False  ...        False  False    False
# 2          12    11413   False      False  ...        False  False    False
# 3          17    61614   False      False  ...        False  False    False
# 4           1    95370   False      False  ...        False  False    False
#
# ...

# %%
mov_rat_use_table.tail()
# Out:
#          MovieID                  Title          Genres  UserID Gender  Age  \
# 1000204     3952  Contender, The (2000)  Drama|Thriller    5812      F   25
# 1000205     3952  Contender, The (2000)  Drama|Thriller    5831      M   25
# 1000206     3952  Contender, The (2000)  Drama|Thriller    5837      M   25
# 1000207     3952  Contender, The (2000)  Drama|Thriller    5927      M   35
# 1000208     3952  Contender, The (2000)  Drama|Thriller    5998      M   18
#
#          Occupation Zip-code  Action  Adventure  ...  Documentary  Drama  \
# 1000204           7    92120   False      False  ...        False   True
# 1000205           1    92120   False      False  ...        False   True
# 1000206           7    60607   False      False  ...        False   True
# 1000207          14    10003   False      False  ...        False   True
# 1000208           4    61820   False      False  ...        False   True
#
# ...

# %%
for gen in gen_list:
    mov_rat_use_table[gen] = mov_rat_use_table[gen]*1

# %%
# true / false into  1/0
mov_rat_use_table
# Out:
#          MovieID                  Title          Genres  UserID Gender  Age  \
# 1000204     3952  Contender, The (2000)  Drama|Thriller    5812      F   25
# 1000205     3952  Contender, The (2000)  Drama|Thriller    5831      M   25
# 1000206     3952  Contender, The (2000)  Drama|Thriller    5837      M   25
# 1000207     3952  Contender, The (2000)  Drama|Thriller    5927      M   35
# 1000208     3952  Contender, The (2000)  Drama|Thriller    5998      M   18
#
#          Occupation Zip-code  Action  Adventure  ...  Documentary  Drama  \
# 1000204           7    92120       0          0  ...            0      1
# 1000205           1    92120       0          0  ...            0      1
# 1000206           7    60607       0          0  ...            0      1
# 1000207          14    10003       0          0  ...            0      1
# 1000208           4    61820       0          0  ...            0      1
#
# ...

# %%
movie_ratings = pd.pivot_table(df,index = 'MovieID',columns = 'UserID', values = 'Rating').reset_index()
movie_ratings
# Out:
# UserID  MovieID    1   2   3   4   5  ...  6035  6036  6037  6038  6039  6040
# 0             1  5.0 NaN NaN NaN NaN  ...   4.0   NaN   NaN   NaN   NaN   3.0
# 1             2  NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2             3  NaN NaN NaN NaN NaN  ...   1.0   NaN   NaN   NaN   NaN   NaN
# 3             4  NaN NaN NaN NaN NaN  ...   2.0   2.0   NaN   NaN   NaN   NaN
# 4             5  NaN NaN NaN NaN NaN  ...   1.0   NaN   NaN   NaN   NaN   NaN
# ...         ...  ...  ..  ..  ..  ..  ...   ...   ...   ...   ...   ...   ...
# 3701       3948  NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3702       3949  NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3703       3950  NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3704       3951  NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3705       3952  NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
# [3706 rows x 6041 columns]

# %%
sim_users = movie_ratings.corr().reset_index() # corr(method='pearson')
print(sim_users)
# Out:
# UserID   UserID   MovieID         1  ...      6038      6039      6040
# 0       MovieID  1.000000 -0.118168  ... -0.247175 -0.092019 -0.161112
# 1             1 -0.118168  1.000000  ...       NaN  0.056857 -0.043519
# 2             2 -0.094652  0.416667  ... -0.500000  0.572078 -0.027143
# 3             3 -0.161199 -0.332182  ...  0.500000  0.309277 -0.395285
# 4             4 -0.153216  0.333333  ... -1.000000  0.000000  0.450323
# ...         ...       ...       ...  ...       ...       ...       ...
# 6036       6036 -0.063169 -0.201132  ... -0.118345  0.186261  0.352849
# 6037       6037 -0.128420 -0.451754  ... -1.000000  0.129522  0.165982
# 6038       6038 -0.247175       NaN  ...  1.000000  0.271163 -0.397122
# 6039       6039 -0.092019  0.056857  ...  0.271163  1.000000  0.242309
# 6040       6040 -0.161112 -0.043519  ... -0.397122  0.242309  1.000000
#
# [6041 rows x 6042 columns]

# %%
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 6001
# 6002
# 6003
# 6006
# 6007
# 6010
# 6013
# 6014
# 6016
# 6018
# 6021
# 6031
# 6037
# 6039
# 6040
# 1
# 6
# 10
# 17
# 18
# 19
# 23
# 26
# 33
# 35
# 36
# 48
# 49
# 53
# 58
# 65
# 75
# 92
# 93
# 102
# 112
# 114
# 117
# 119
# 131
# 136
# 137
# 139
# 142
# 146
# 150
# 162
# 163
# 169
# 184
# 186
# 187
# 192
# 204
# 225
# 229
# 233
# 235
# 239
# 242
# 246
# 264
# 265
# 266
# 268
# 271
# 281
# 284
# 296
# 301
# 302
# 305
# 307
# 308
# 310
# 314
# 317
# 321
# 329
# 333
# 337
# 340
# 343
# 355
# 366
# 377
# 389
# 392
# 401
# 403
# 411
# 412
# 413
# 417
# 424
# 438
# 454
# 462
# 470
# 474
# 490
# 500
# 509
# 517
# 520
# 525
# 528
# 531
# 536
# 539
# 541
# 543
# 544
# 549
# 550
# 556
# 563
# 566
# 570
# 583
# 585
# 601
# 614
# 624
# 629
# 631
# 634
# 637
# 639
# 646
# 658
# 662
# 664
# 666
# 669
# 678
# 681
# 690
# 696
# 699
# 702
# 705
# 713
# 714
# 715
# 716
# 718
# 720
# 721
# 727
# 729
# 733
# 735
# 739
# 746
# 749
# 753
# 765
# 767
# 770
# 774
# ...
